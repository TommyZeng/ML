# %%
import numpy as np
import math
np.random.permutation(148)
# Out:
# array([ 40,  90,  48,  41,   5, 103,  85,  89,  75, 132,  73, 107,  92,
#        126,  88,  87,  51,  96,  15,  27,  43,  72, 129,  82,  10, 120,
#         97,  14,  29,  45,  54,  35,  49, 123,  86, 144,   7,  66,  26,
#         34,  76, 108,  78, 142, 100,  18,  74,  94,  56, 109, 119,  84,
#         91, 112,  20, 104, 133, 111, 121,  44,  68, 125,   9,  98, 136,
#        116,  30,  63,  23, 114,  57, 128, 124,  36,  95,   6, 105,  80,
#        140,  71,  37, 143, 146, 115,  39, 139,  64,  46,   0,  81,  16,
#         24,  28, 127,  77,  33,  19,  79,   8,  47,  53,  25,  99, 141,
#        135,  58,  11,  61,  59, 137,  22,  12,   1, 147, 106,  42,  50,
#        110,   3,  38, 131, 138, 134,  13,  67,  32,  31, 113, 122,  65,
#         55,  62,  60,   2, 117,  83, 145, 102,  52,  69,  70,  21,  93,
#        130, 101,  17,   4, 118])

# %%
math.floor(10 / 2)
# Out:
# 5

# %%
a = np.random.rand(1,10)
permutation = list(np.random.permutation(10))
print(permutation)
a
# Out:
# [8, 4, 2, 9, 1, 7, 5, 6, 3, 0]
# array([[0.23249631, 0.39460403, 0.96341872, 0.93377382, 0.15257957,
#         0.74439596, 0.14292753, 0.20835534, 0.74287067, 0.6956304 ]])

# %%
shuffled_X = a[:,permutation]
shuffled_X
# Out:
# array([[0.74287067, 0.15257957, 0.96341872, 0.6956304 , 0.39460403,
#         0.20835534, 0.74439596, 0.14292753, 0.93377382, 0.23249631]])

# %%
# -*- coding: utf-8 -*-
import numpy as np
import matplotlib.pyplot as plt
import scipy.io
import math
import sklearn
import sklearn.datasets

import opt_utils #参见数据包或者在本文底部copy
import testCase  #参见数据包或者在本文底部copy

# %matplotlib inline 
plt.rcParams['figure.figsize'] = (7.0, 4.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'


train_X, train_Y = opt_utils.load_dataset(is_plot=True)
